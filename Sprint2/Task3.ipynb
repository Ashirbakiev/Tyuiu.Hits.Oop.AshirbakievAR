// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания 2

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// <b>Описание задачи:</b>
// Создать базовый класс Student в C#, который будет представлять информацию о
// студентах. На основе этого класса разработать 2-3 производных класса,
// демонстрирующих принципы наследования и полиморфизма. В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.
//
// <b>Требования к базовому классу Student:</b><br>
// • Атрибуты: Имя (Name), Возраст (Age), Курс (Course).<br>
// • Методы:
// o GetInfo(): метод для получения информации о студенте в виде строки.
// o Study(): метод для вывода сообщения о том, что студент учится.
// o TakeExam(): метод для вывода сообщения о сдаче экзамена.
// <b>Требования к производным классам:</b>
// 1. Студент бакалавриата (BachelorStudent): Должен содержать дополнительные
// атрибуты, такие как Специальность (Specialty). Метод Study() должен быть
// переопределен для добавления информации о специальности при изучении
// предмета.
// 2. Студент магистратуры (MasterStudent): Должен содержать дополнительные
// атрибуты, такие как Научный руководитель (ScientificAdvisor).
// Метод TakeExam() должен быть переопределен для добавления
// информации о научном руководителе при сдаче экзамена.
// 3. Аспирант (PhDStudent) (если требуется третий класс): Должен содержать
// дополнительные атрибуты, такие как Тема диссертации (DissertationTopic).
// Метод Study() должен быть переопределен для добавления информации о
// теме диссертации при изучении предмета.<br>
//
// <b>Дополнительное задание</b><br>
// Добавьте к сущестующим классам (базовыму и производным 3-4 атрибута и метода) и реализуйте простое, сложное и множественное наследование

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;

// Базовый класс Student
class Student
{
    public string Name { get; set; }
    public int Age { get; set; }
    public string Course { get; set; }
    public double GPA { get; set; }  // Средний балл
    public string University { get; set; }  // Университет

    public Student(string name, int age, string course, double gpa, string university)
    {
        Name = name;
        Age = age;
        Course = course;
        GPA = gpa;
        University = university;
    }

    public virtual string GetInfo()
    {
        return $"Имя: {Name}, Возраст: {Age}, Курс: {Course}, Средний балл: {GPA}, Университет: {University}";
    }

    public virtual void Study()
    {
        Console.WriteLine($"{Name} учится в университете {University}.");
    }

    public virtual void TakeExam()
    {
        Console.WriteLine($"{Name} сдает экзамен.");
    }

    public void AttendLecture()
    {
        Console.WriteLine($"{Name} посещает лекцию.");
    }
}

// Интерфейс для дополнительных возможностей
interface IResearch
{
    void ConductResearch(); // Метод для проведения исследований
    void PublishPaper();    // Метод для публикации статей
}

// Класс BachelorStudent с простым наследованием
class BachelorStudent : Student
{
    public string Specialty { get; set; }
    public int Year { get; set; } // Год обучения
    public string InternshipCompany { get; set; } // Компания для стажировки

    public BachelorStudent(string name, int age, string course, double gpa, string university, string specialty, int year, string internshipCompany)
        : base(name, age, course, gpa, university)
    {
        Specialty = specialty;
        Year = year;
        InternshipCompany = internshipCompany;
    }

    public override void Study()
    {
        Console.WriteLine($"{Name} учится на специальности {Specialty} в {Year} году обучения.");
    }

    public void ApplyForInternship()
    {
        Console.WriteLine($"{Name} подает заявку на стажировку в компанию {InternshipCompany}.");
    }
}

// Класс MasterStudent с простым наследованием и реализацией интерфейса IResearch (множественное наследование через интерфейс)
class MasterStudent : Student, IResearch
{
    public string ScientificAdvisor { get; set; }
    public string ResearchTopic { get; set; } // Тема исследования
    public int Publications { get; set; } // Количество публикаций

    public MasterStudent(string name, int age, string course, double gpa, string university, string scientificAdvisor, string researchTopic, int publications)
        : base(name, age, course, gpa, university)
    {
        ScientificAdvisor = scientificAdvisor;
        ResearchTopic = researchTopic;
        Publications = publications;
    }

    public override void TakeExam()
    {
        Console.WriteLine($"{Name} сдает экзамен под руководством {ScientificAdvisor}.");
    }

    public void ConductResearch()
    {
        Console.WriteLine($"{Name} проводит исследование на тему '{ResearchTopic}'.");
    }

    public void PublishPaper()
    {
        Console.WriteLine($"{Name} публикует научную статью. Всего опубликованных статей: {Publications}.");
    }
}

// Класс PhDStudent с простым наследованием и реализацией интерфейса IResearch (множественное наследование через интерфейс)
class PhDStudent : Student, IResearch
{
    public string DissertationTopic { get; set; }
    public string Supervisor { get; set; } // Научный руководитель
    public int ResearchYears { get; set; } // Количество лет исследований

    public PhDStudent(string name, int age, string course, double gpa, string university, string dissertationTopic, string supervisor, int researchYears)
        : base(name, age, course, gpa, university)
    {
        DissertationTopic = dissertationTopic;
        Supervisor = supervisor;
        ResearchYears = researchYears;
    }

    public override void Study()
    {
        Console.WriteLine($"{Name} работает над диссертацией на тему '{DissertationTopic}' под руководством {Supervisor}.");
    }

    public void ConductResearch()
    {
        Console.WriteLine($"{Name} проводит исследования уже {ResearchYears} лет.");
    }

    public void PublishPaper()
    {
        Console.WriteLine($"{Name} публикует статью по теме диссертации '{DissertationTopic}'.");
    }

    public void DefendThesis()
    {
        Console.WriteLine($"{Name} защищает свою диссертацию.");
    }
}


BachelorStudent bachelor = new BachelorStudent("Алиса", 20, "Компьютерные науки", 3.5, "Тюменский Государственный Университет", "Программная инженерия", 3, "Google");
MasterStudent master = new MasterStudent("Боб", 24, "Компьютерные науки", 3.8, "Тюменский Государственный Университет", "доктор Смит", "Машинное обучение", 5);
PhDStudent phd = new PhDStudent("Чарли", 28, "Компьютерные науки", 4.0, "Тюменский Государственный Университет", "Искусственный интеллект", "профессор Иванов", 4);

Console.WriteLine(bachelor.GetInfo());
bachelor.Study();
bachelor.TakeExam();
bachelor.AttendLecture();
bachelor.ApplyForInternship();

Console.WriteLine(master.GetInfo());
master.Study();
master.TakeExam();
master.AttendLecture();
master.ConductResearch();
master.PublishPaper();

Console.WriteLine(phd.GetInfo());
phd.Study();
phd.TakeExam();
phd.AttendLecture();
phd.ConductResearch();
phd.PublishPaper();
phd.DefendThesis();
// Out:
// Имя: Алиса, Возраст: 20, Курс: Компьютерные науки, Средний балл: 3,5, Университет: Тюменский Государственный Университет
// Алиса учится на специальности Программная инженерия в 3 году обучения.
// Алиса сдает экзамен.
// Алиса посещает лекцию.
// Алиса подает заявку на стажировку в компанию Google.
// Имя: Боб, Возраст: 24, Курс: Компьютерные науки, Средний балл: 3,8, Университет: Тюменский Государственный Университет
// Боб учится в университете Тюменский Государственный Университет.
// Боб сдает экзамен под руководством доктор Смит.
// Боб посещает лекцию.
// Боб проводит исследование на тему 'Машинное обучение'.
// Боб публикует научную статью. Всего опубликованных статей: 5.
// Имя: Чарли, Возраст: 28, Курс: Компьютерные науки, Средний балл: 4, Университет: Тюменский Государственный Университет
// Чарли работает над диссертацией на тему 'Искусственный интеллект' под руководством профессор Иванов.
// Чарли сдает экзамен.
// Чарли посещает лекцию.
// Чарли проводит исследования уже 4 лет.
// Чарли публикует статью по теме диссертации 'Искусственный интеллект'.
// Чарли защищает свою диссертацию.
